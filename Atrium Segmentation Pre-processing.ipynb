# %% [markdown]
# # Imports:
# * Pathlib for easy path handling
# * nibabel as the files are provided in the NIfTI format
# * numpy for data saving and processing
# * matplotlib for plotting
# * tqdm for nice progressing bars

# %%
pip install nibabel
# Out:
# Requirement already satisfied: nibabel in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (5.2.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.20 in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nibabel) (1.23.5)
# Requirement already satisfied: packaging>=17 in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nibabel) (23.0)
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: C:\Users\riddhi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# %matplotlib notebook
from pathlib import Path
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %%
root = Path("C:\\Users\\riddhi\\OneDrive\\Desktop\\Codes\\06-Atrium-Segmentation\\Task02_Heart\\imagesTr")
label = Path("C:\\Users\\riddhi\\OneDrive\\Desktop\\Codes\\06-Atrium-Segmentation\\Task02_Heart\\labelsTr")

# %%
def change_img_to_label_path(path):
    """
    Replaces imagesTr with labelsTr
    """
    parts = list(path.parts)  # get all directories within the path
    parts[parts.index("imagesTr")] = "labelsTr"  # Replace imagesTr with labelsTr
    return Path(*parts)  # Combine list back into a Path object

# %%
sample_path = list(root.glob("la*"))[0]  # Choose a subject
sample_path_label = change_img_to_label_path(sample_path)

# %%
sample_path, sample_path_label
# Out:
# (WindowsPath('C:/Users/riddhi/OneDrive/Desktop/Codes/06-Atrium-Segmentation/Task02_Heart/imagesTr/la_003.nii.gz'),
#  WindowsPath('C:/Users/riddhi/OneDrive/Desktop/Codes/06-Atrium-Segmentation/Task02_Heart/labelsTr/la_003.nii.gz'))

# %% [markdown]
# # Load NIfTI and extract image data

# %%
data = nib.load(sample_path)
label = nib.load(sample_path_label)

mri = data.get_fdata()
mask = label.get_fdata().astype(np.uint8)  # Class labels should not be handled as float64

# %%
nib.aff2axcodes(data.affine)
# Out:
# ('R', 'A', 'S')

# %%
pip install celluloid
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: celluloid in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.2.0)
# Requirement already satisfied: matplotlib in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from celluloid) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->celluloid) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->celluloid) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->celluloid) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->celluloid) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->celluloid) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->celluloid) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->celluloid) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->celluloid) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->celluloid) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->celluloid) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-resources>=3.2.0->matplotlib->celluloid) (3.13.0)
# Requirement already satisfied: six>=1.5 in c:\users\riddhi\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib->celluloid) (1.16.0)
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: C:\Users\riddhi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from celluloid import Camera
from IPython.display import HTML

# %%
fig = plt.figure()
camera = Camera(fig)  # Create the camera object from celluloid

for i in range(mri.shape[2]):  # Sagital view
    plt.imshow(mri[:,:,i], cmap="bone")
    mask_ = np.ma.masked_where(mask[:,:,i]==0, mask[:,:,i])
    plt.imshow(mask_, alpha=0.5, cmap="autumn")
    # plt.axis("off")
    camera.snap()  # Store the current slice
animation = camera.animate()  # Create the animation
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
HTML(animation.to_html5_video())  # convert the animation to a video

# %% [markdown]
# #  Preprocessing
# We perform the following preprocessing steps:
#
# 1. Normalization per subject. We compute mean and sigma of the full 3d volume $X$ and then perform z-normalization:
# $$X_n = \frac{X-\mu}{\sigma}$$
# 2. There is a plenty of empty space around the image, so we can crop the image (e.g 32 px from top and bottom). Additionally, we can crop away non-cardiac regions as they will definitely not contain the left atrium. This will  reduce training time due to the smaller size and will simplify the segmentation. It is important to crop first and to normalize afterwards. Otherwise the included zero values introduce skewness to the intesity distribution.
# 3. Standardize the normalized subject into the 0-1 range:
# $$X_s = \frac{X_n - min(X_n)}{max(X_n)-min(X_n)} $$
# 4. This task will be performed on a slice level (2D) and not on a subject level (3D). In order to reduce the computational cost we store the preprocessed data as npy files of 2d slices. Reading a single slice is much faster than loading the complete NIfTI file every time.

# %%
# Helper functions for normalization and standardization
def normalize(full_volume):
    """
    Z-Normalization of the whole subject
    """
    mu = full_volume.mean()
    std = np.std(full_volume)
    normalized = (full_volume - mu) / std
    return normalized

def standardize(normalized_data):
    """
    Standardize the normalized data into the 0-1 range
    """
    standardized_data = (normalized_data - normalized_data.min()) / (normalized_data.max() - normalized_data.min())
    return standardized_data

# %%
def normalize(full_volume):
    mu = full_volume.mean()
    std = np.std(full_volume)
    normalized = (full_volume - mu) / std
    return normalized

def standardize(normalized):
    standardized = (normalized - normalized.min()) / (normalized.max() - normalized.min())
    return standardized

# %%
all_files = list(root.glob("la*"))  # Get all subjects
len(all_files)

# %%
save_root = Path("C:\\Users\\riddhi\\OneDrive\\Desktop\\Codes\\06-Atrium-Segmentation\\Preprocessed")

for counter, path_to_mri_data in enumerate(tqdm(all_files)):
    
    path_to_label = change_img_to_label_path(path_to_mri_data)
    
    mri = nib.load(path_to_mri_data)
    assert nib.aff2axcodes(mri.affine) == ("R", "A", "S")    
    mri_data = mri.get_fdata()
    label_data = nib.load(path_to_label).get_fdata().astype(np.uint8)
    
    # Crop volume and label mask. Reduce 32 px from top and 32 px from bottom.
    # Addtionally crop front and back with same size. Dont crop viewing axis
    mri_data = mri_data[32:-32, 32:-32]
    label_data = label_data[32:-32, 32:-32]
    
    # Normalize and standardize the images
    normalized_mri_data = normalize(mri_data)
    standardized_mri_data = standardize(normalized_mri_data)
    
    # Check if train or val data and create corresponding path
    if counter < 17:
        current_path = save_root/"train"/str(counter)
    else:
        current_path = save_root/"val"/str(counter)
    
    # Loop over the slices in the full volume and store the images and labels in the data/masks directory
    for i in range(standardized_mri_data.shape[-1]):
        slice = standardized_mri_data[:,:,i]
        mask = label_data[:,:,i]
        slice_path = current_path/"data"
        mask_path = current_path/"masks"
        slice_path.mkdir(parents=True, exist_ok=True)
        mask_path.mkdir(parents=True, exist_ok=True)
        
        np.save(slice_path/str(i), slice)
        np.save(mask_path/str(i), mask)

# %% [markdown]
# # Validate preprocessed data
# Now, we can take a look at the stored files and inspect if everything works

# %%
path = Path("C:\\Users\\riddhi\\OneDrive\\Desktop\\Codes\\06-Atrium-Segmentation\\Preprocessed\\train\\1\\")  # Select a subject

# %%
# Choose a file and load slice + mask
file = "50.npy"
slice = np.load(path/"data"/file)
mask = np.load(path/"masks"/file)

# %%
# Plot everything
plt.figure()
plt.imshow(slice, cmap="bone")
mask_ = np.ma.masked_where(mask==0, mask)
plt.imshow(mask_, cmap="autumn")

# %%
print(slice.min(), slice.max())
